# %% [markdown]
# # ALM — Exploratory Analysis
#
# This notebook is for exploratory analysis and rapid prototyping.
# Validated code should be refactored into `src/`.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "..")
